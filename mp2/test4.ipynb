# %%
import sys
sys.path.append("..")

import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
from reader import generic_reader

# %%
import myplot

# %%
import numpy as np
data = np.random.normal(170, 10, 250)

# %%
myplot.plot_normal_fit(data)
