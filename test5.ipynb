# %%
import f1_reader
import pandas as pd

# %%
directory = "html"

results = {}
for year in range(2020, 2025):
    results[year] = f1_reader.read_f1_season_from_html_files_to_dictionary(year, directory)

# %%
races_per_season = {year: len(season) for year, season in results.items()}

# %%
print(races_per_season)
# Out:
# {2020: 17, 2021: 22, 2022: 22, 2023: 22, 2024: 24}

# %%
my_series = pd.Series(races_per_season)
print(my_series)
my_series.plot(kind="bar")
# Out:
# 2020    17
# 2021    22
# 2022    22
# 2023    22
# 2024    24
# dtype: int64
# <Axes: >

# %%
# Out:
# 2020    17
# 2021    22
# 2022    22
# 2023    22
# 2024    24
# dtype: int64

# %%
my_series.plot(kind="bar", title="Races per season", xlabel="Season", ylabel="Races per season")
# Out:
# <Axes: title={'center': 'R'}, xlabel='Season', ylabel='Races per season'>
