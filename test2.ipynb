# %%
import pandas as pd

# Sample DataFrame
fruit_data = pd.DataFrame({
    'Fruits': [30, 45, 25]
}, index=['Apples', 'Bananas', 'Cherries'])

# Pie chart from DataFrame
fruit_data.plot.pie(y='Fruits', autopct='%1.1f%%', figsize=(5, 5), legend=False)
# plt.ylabel('')  # Hide y-label
# plt.title('Fruit Distribution')
# plt.show()
# Out:
# <Axes: ylabel='Fruits'>
